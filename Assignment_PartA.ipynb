# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.8/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/conda/lib/python3.8/site-packages (from pymongo) (2.3.0)

# %% [markdown]
# # Justification of the model with example:
#
# For the assignemnt I used embedded model as we have pre saved csv dataset and there would be no new data added. For quicker data read embedded model is preferred above reference model which might have been useful for requirements to have more write operations.
#
# The dataset 'climate_historic' contains only one record is produced per day. While the dataset 'hotspot_historic' can have zero to many records on a single day. As a result, using the date as the connecting data point between to the two collections, we can model a one-to-many relationship, where a climate record, can have many hotspot records. Thus in need of extraction of information about hotspots we can query easily using embedded model as it would have all the hotspot data for a particular day in single document based on climate_historic dataset. Which for reference model case would require more queries to be made for the same result. It aslo eliminates the need for joins. Another important benefit, is that operations peformed on a embedded model is always atomic, whilst in a reference model, atomic operations can never be assumed.
#
# A potential problem with this approach is that this can lead to large documents, especially when in this case, a 'climate' may have a large subset of 'hotspots'. However we have 4mb space provided for a single document and based on that it can server much more than 100 hotspot documenets too for a single day, which can't happen in a single day, but the capacity is there for the model to hold the data based on that.
#
# Example
#
#
# {'_id': ObjectId('647cc92054ffcc378202d047'),
#
#  'air_temperature_celcius': 14.0,
#
#  'date': datetime.datetime(2022, 11, 9, 0, 0),
#
#  'ghi': 119.0,
#
#  'hotspots': {'confidence': 100.0,
#
#               'latitude': -37.477,
#
#               'longitude': 143.352,
#
#               'surface_temperature_celcius': 93.0,
#
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 48)},
#
#  'max_wind_speed': 13.0,
#
#  'precipitation': 0.0,
#
#  'precipitation_type': 'I',
#
#  'relative_humidity': 50.9,
#
#  'station': 948702,
#
#  'windspeed_knots': 5.9}

# %%
from datetime import datetime
from pprint import pprint
from pymongo import MongoClient
import pymongo
import pandas

# %%
# Connect to MongoClient & get/create assignment database
client = pymongo.MongoClient('192.168.1.5', 27017)
db = client.fit3182_assignment_db
collection = db.FIT_COMPLEX

# Drop existing collection, to reload data from CSV
collection.drop()

# Read data from CSV using pandas
hotspot_data = pandas.read_csv('hotspot_historic.csv')
climate_data = pandas.read_csv('climate_historic.csv')

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
# Connect to MongoClient & get/create assignment database
client = pymongo.MongoClient('192.168.1.5', 27017)
db = client.fit3182_assignment_db
collection = db.FIT_COMPLEX

# Drop existing collection, to reload data from CSV
collection.drop()

# Read data from CSV using pandas
hotspot_data = pandas.read_csv('hotspot_historic.csv')
climate_data = pandas.read_csv('climate_historic.csv')

# %%
# Read data from CSV using pandas
hotspot_data = pandas.read_csv('hotspot_historic.csv')
climate_data = pandas.read_csv('climate_historic.csv')

collection_data = []

for index, row in climate_data.iterrows():
    document = {}

    # Format data appropriately for document object.
    document['date'] = datetime.strptime(row['date'], '%d/%m/%Y')
    document['station'] = int(row['station'])
    document["air_temperature_celcius"] = float(
        row["air_temperature_celcius"])
    document['relative_humidity'] = float(row['relative_humidity'])
    document['windspeed_knots'] = float(row['windspeed_knots'])
    document['max_wind_speed'] = float(row['max_wind_speed'])

    # Unncessary space at beginning of value is removed.
    # Also split precipation type and amount, to make it easier for sorting/searching later.
    precipitation = str(row['precipitation ']).replace(" ", "")
    document['precipitation_type'] = precipitation[-1]

    document['precipitation'] = float(precipitation[0:-1])
    document['ghi'] = float(row['GHI_w/m2'])

    # Get all hotspot records that match climate date & append to document.
    hotspot_date = document['date'].strftime("%-d/%m/%Y")
    
    hotspots = hotspot_data[hotspot_data['date'] == hotspot_date]

    # If there is a match, we clean up data & append records to document.
    if len(hotspots) > 0:
        document['hotspots'] = []
        for index, row in hotspots.iterrows():
            hotspot = {}
            hotspot['time'] = datetime.strptime(
                row['datetime'], '%Y-%m-%dT%H:%M:%S')
            hotspot['latitude'] = float(row['latitude'])
            hotspot['longitude'] = float(row['longitude'])
            hotspot['confidence'] = float(row['confidence'])
            hotspot['surface_temperature_celcius'] = float(
                row['surface_temperature_celcius'])
            document['hotspots'].append(hotspot)

    collection_data.append(document)
    
# Insert collection into database
collection.insert_many(collection_data)

# %%
result = collection.find_one({'date': datetime(2022, 12, 12)})
pprint(result)
# Out:
# {'_id': ObjectId('647f20bc02b5db9ca3359da8'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2022, 12, 12, 0, 0),
#  'ghi': 156.0,
#  'hotspots': [{'confidence': 53.0,
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44.0,
#                'time': datetime.datetime(2022, 12, 12, 0, 45, 38)}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$match': {'hotspots.surface_temperature_celcius': {'$gte': 65, '$lte': 100}}}, {
    '$project': {'_id': 0, 'hotspots.longitude': 1, 'hotspots.latitude': 1, 'hotspots.surface_temperature_celcius': 1}}])

for each in result:
    pprint(each)
# Out:
# {'hotspots': {'latitude': -37.462,
#               'longitude': 148.089,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.46,
#               'longitude': 148.102,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -37.331,
#               'longitude': 143.122,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.477,
#               'longitude': 143.352,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -37.475,
#               'longitude': 143.365,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.69,
#               'longitude': 143.605,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.862,
#               'longitude': 144.175,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.282,
#               'longitude': 146.157,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.966,
#               'longitude': 145.051,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celcius': 67.0}}

# %%
result = collection.find({'date': {'$in': [datetime(2022, 12, 15), datetime(2022, 12, 16)]}}, {
    '_id': 0, 'date': 1, 'hotspots.surface_temperature_celcius': 1, 'air_temperature_celcius': 1, 'relative_humidity': 1, 'max_wind_speed': 1})

for each in result:
    pprint(each)
# Out:
# {'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2022, 12, 15, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 42.0},
#               {'surface_temperature_celcius': 36.0},
#               {'surface_temperature_celcius': 38.0},
#               {'surface_temperature_celcius': 40.0}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2022, 12, 16, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 43.0},
#               {'surface_temperature_celcius': 33.0},
#               {'surface_temperature_celcius': 54.0},
#               {'surface_temperature_celcius': 73.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 75.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 66.0},
#               {'surface_temperature_celcius': 56.0},
#               {'surface_temperature_celcius': 60.0},
#               {'surface_temperature_celcius': 73.0},
#               {'surface_temperature_celcius': 48.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 64.0},
#               {'surface_temperature_celcius': 57.0}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$match': {'hotspots.confidence': {'$gte': 80, '$lte': 100}}}, {
    '$project': {'_id': 0, 'hotspots.time': 1, 'air_temperature_celcius': 1, 'hotspots.surface_temperature_celcius': 1, 'hotspots.confidence': 1}}])

for each in result:
    pprint(each)
# Out:
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 10, 1, 15, 13, 56)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2022, 10, 1, 4, 10, 28)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2022, 10, 1, 4, 10, 28)}}
# {'air_temperature_celcius': 11.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2022, 10, 2, 4, 53, 10)}}
# {'air_temperature_celcius': 11.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2022, 10, 2, 4, 53, 9)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 10, 3, 13, 23, 43)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 15)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 15)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 15)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 15)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 15)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 14)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 14)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 14)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2022, 10, 4, 4, 41, 2)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2022, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2022, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 10, 7, 12, 59, 33)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2022, 10, 10, 4, 4, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2022, 10, 15, 4, 23, 1)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 85.0,
#               'time': datetime.datetime(2022, 10, 15, 4, 23, 1)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2022, 10, 17, 13, 36, 12)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2022, 10, 17, 4, 10, 45)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 10, 17, 4, 10, 32)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 10, 18, 0, 39, 2)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2022, 10, 18, 0, 39, 2)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2022, 10, 20, 4, 41, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2022, 10, 20, 4, 41, 19)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 10, 21, 1, 9, 55)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2022, 10, 21, 1, 9, 54)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2022, 10, 26, 13, 30, 31)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2022, 10, 26, 13, 30, 31)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 10, 27, 4, 47, 31)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2022, 10, 28, 3, 52, 17)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2022, 11, 5, 4, 41, 34)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2022, 11, 5, 4, 41, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2022, 11, 5, 4, 41, 19)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 93.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 44)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 44)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2022, 11, 11, 13, 30, 8)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 11, 11, 13, 30, 8)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 11, 11, 4, 4, 25)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 69.0,
#               'time': datetime.datetime(2022, 11, 12, 0, 33, 15)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2022, 11, 13, 3, 52, 15)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2022, 11, 13, 3, 52, 14)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2022, 11, 14, 4, 35, 4)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 11, 21, 0, 27, 21)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 11, 22, 3, 46)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2022, 11, 22, 3, 46)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 11, 23, 4, 28, 59)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2022, 11, 23, 4, 28, 59)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 11, 29, 13, 17, 24)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 84.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 36)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 14)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 83.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 12, 8, 13, 11, 44)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2022, 12, 8, 13, 11, 44)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2022, 12, 8, 13, 11, 43)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2022, 12, 9, 0, 14, 34)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 12, 9, 0, 14, 34)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2022, 12, 9, 0, 14, 33)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 12, 9, 0, 14, 33)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 12, 13, 4, 4, 19)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': datetime.datetime(2022, 12, 14, 4, 47, 25)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 12, 15, 13, 17, 17)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2022, 12, 16, 15, 38, 39)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 35, 13)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 34, 58)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 34, 58)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 34, 57)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2022, 12, 16, 0, 21, 12)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 12, 16, 0, 21, 11)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2022, 12, 16, 0, 20, 53)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 12, 25, 4, 29, 8)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2022, 12, 27, 0, 2, 15)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2022, 12, 27, 0, 2, 14)}}

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {
    '$sort': {'hotspots.surface_temperature_celcius': -1}}, {'$limit': 10}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('647f20bc02b5db9ca3359d87'),
#  'air_temperature_celcius': 14.0,
#  'date': datetime.datetime(2022, 11, 9, 0, 0),
#  'ghi': 119.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.477,
#               'longitude': 143.352,
#               'surface_temperature_celcius': 93.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 48)},
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 50.9,
#  'station': 948702,
#  'windspeed_knots': 5.9}
# {'_id': ObjectId('647f20bc02b5db9ca3359d62'),
#  'air_temperature_celcius': 13.0,
#  'date': datetime.datetime(2022, 10, 3, 0, 0),
#  'ghi': 115.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.462,
#               'longitude': 148.089,
#               'surface_temperature_celcius': 90.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 14)},
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 5.6}
# {'_id': ObjectId('647f20bc02b5db9ca3359d6e'),
#  'air_temperature_celcius': 13.0,
#  'date': datetime.datetime(2022, 10, 15, 0, 0),
#  'ghi': 111.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2022, 10, 15, 4, 23, 1)},
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 50.7,
#  'station': 948702,
#  'windspeed_knots': 6.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9b'),
#  'air_temperature_celcius': 28.0,
#  'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'ghi': 227.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)},
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9c'),
#  'air_temperature_celcius': 26.0,
#  'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'ghi': 202.0,
#  'hotspots': {'confidence': 99.0,
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d6e'),
#  'air_temperature_celcius': 13.0,
#  'date': datetime.datetime(2022, 10, 15, 0, 0),
#  'ghi': 111.0,
#  'hotspots': {'confidence': 99.0,
#               'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85.0,
#               'time': datetime.datetime(2022, 10, 15, 4, 23, 1)},
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 50.7,
#  'station': 948702,
#  'windspeed_knots': 6.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9b'),
#  'air_temperature_celcius': 28.0,
#  'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'ghi': 227.0,
#  'hotspots': {'confidence': 99.0,
#               'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)},
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9c'),
#  'air_temperature_celcius': 26.0,
#  'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'ghi': 202.0,
#  'hotspots': {'confidence': 98.0,
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9b'),
#  'air_temperature_celcius': 28.0,
#  'date': datetime.datetime(2022, 11, 29, 0, 0),
#  'ghi': 227.0,
#  'hotspots': {'confidence': 97.0,
#               'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)},
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d87'),
#  'air_temperature_celcius': 14.0,
#  'date': datetime.datetime(2022, 11, 9, 0, 0),
#  'ghi': 119.0,
#  'hotspots': {'confidence': 97.0,
#               'latitude': -37.69,
#               'longitude': 143.605,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 44)},
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 50.9,
#  'station': 948702,
#  'windspeed_knots': 5.9}

# %%
result = collection.aggregate(
    [{'$project': {'_id': 0, 'date': 1, 'numberOfFires': {'$size': {'$ifNull': ['$hotspots', []]}}}}])

for each in result:
    pprint({
        "date": each['date'].strftime("%d/%m/%Y"),
        "numberOfFires": each['numberOfFires']
    })
# Out:
# {'date': '31/12/2021', 'numberOfFires': 0}
# {'date': '02/01/2022', 'numberOfFires': 0}
# {'date': '03/01/2022', 'numberOfFires': 0}
# {'date': '04/01/2022', 'numberOfFires': 0}
# {'date': '05/01/2022', 'numberOfFires': 0}
# {'date': '06/01/2022', 'numberOfFires': 0}
# {'date': '07/01/2022', 'numberOfFires': 0}
# {'date': '08/01/2022', 'numberOfFires': 0}
# {'date': '09/01/2022', 'numberOfFires': 0}
# {'date': '10/01/2022', 'numberOfFires': 0}
# {'date': '11/01/2022', 'numberOfFires': 0}
# {'date': '12/01/2022', 'numberOfFires': 0}
# {'date': '13/01/2022', 'numberOfFires': 0}
# {'date': '14/01/2022', 'numberOfFires': 0}
# {'date': '15/01/2022', 'numberOfFires': 0}
# {'date': '16/01/2022', 'numberOfFires': 0}
# {'date': '17/01/2022', 'numberOfFires': 0}
# {'date': '18/01/2022', 'numberOfFires': 0}
# {'date': '19/01/2022', 'numberOfFires': 0}
# {'date': '20/01/2022', 'numberOfFires': 0}
# {'date': '21/01/2022', 'numberOfFires': 0}
# {'date': '22/01/2022', 'numberOfFires': 0}
# {'date': '23/01/2022', 'numberOfFires': 0}
# {'date': '24/01/2022', 'numberOfFires': 0}
# {'date': '25/01/2022', 'numberOfFires': 0}
# {'date': '26/01/2022', 'numberOfFires': 0}
# {'date': '27/01/2022', 'numberOfFires': 0}
# {'date': '28/01/2022', 'numberOfFires': 0}
# {'date': '29/01/2022', 'numberOfFires': 0}
# {'date': '30/01/2022', 'numberOfFires': 0}
# {'date': '31/01/2022', 'numberOfFires': 0}
# {'date': '01/02/2022', 'numberOfFires': 0}
# {'date': '02/02/2022', 'numberOfFires': 0}
# {'date': '03/02/2022', 'numberOfFires': 0}
# {'date': '04/02/2022', 'numberOfFires': 0}
# {'date': '05/02/2022', 'numberOfFires': 0}
# {'date': '06/02/2022', 'numberOfFires': 0}
# {'date': '07/02/2022', 'numberOfFires': 0}
# {'date': '08/02/2022', 'numberOfFires': 0}
# {'date': '09/02/2022', 'numberOfFires': 0}
# {'date': '10/02/2022', 'numberOfFires': 0}
# {'date': '11/02/2022', 'numberOfFires': 0}
# {'date': '12/02/2022', 'numberOfFires': 0}
# {'date': '13/02/2022', 'numberOfFires': 0}
# {'date': '14/02/2022', 'numberOfFires': 0}
# {'date': '15/02/2022', 'numberOfFires': 0}
# {'date': '16/02/2022', 'numberOfFires': 0}
# {'date': '17/02/2022', 'numberOfFires': 0}
# {'date': '18/02/2022', 'numberOfFires': 0}
# {'date': '19/02/2022', 'numberOfFires': 0}
# {'date': '20/02/2022', 'numberOfFires': 0}
# {'date': '21/02/2022', 'numberOfFires': 0}
# {'date': '22/02/2022', 'numberOfFires': 0}
# {'date': '23/02/2022', 'numberOfFires': 0}
# {'date': '24/02/2022', 'numberOfFires': 0}
# {'date': '25/02/2022', 'numberOfFires': 0}
# {'date': '26/02/2022', 'numberOfFires': 0}
# {'date': '27/02/2022', 'numberOfFires': 0}
# {'date': '28/02/2022', 'numberOfFires': 0}
# {'date': '01/03/2022', 'numberOfFires': 0}
# {'date': '02/03/2022', 'numberOfFires': 0}
# {'date': '03/03/2022', 'numberOfFires': 0}
# {'date': '04/03/2022', 'numberOfFires': 0}
# {'date': '05/03/2022', 'numberOfFires': 0}
# {'date': '06/03/2022', 'numberOfFires': 0}
# {'date': '07/03/2022', 'numberOfFires': 0}
# {'date': '08/03/2022', 'numberOfFires': 0}
# {'date': '09/03/2022', 'numberOfFires': 0}
# {'date': '10/03/2022', 'numberOfFires': 0}
# {'date': '11/03/2022', 'numberOfFires': 0}
# {'date': '12/03/2022', 'numberOfFires': 0}
# {'date': '13/03/2022', 'numberOfFires': 0}
# {'date': '14/03/2022', 'numberOfFires': 0}
# {'date': '15/03/2022', 'numberOfFires': 0}
# {'date': '16/03/2022', 'numberOfFires': 0}
# {'date': '17/03/2022', 'numberOfFires': 0}
# {'date': '18/03/2022', 'numberOfFires': 0}
# {'date': '19/03/2022', 'numberOfFires': 0}
# {'date': '20/03/2022', 'numberOfFires': 0}
# {'date': '21/03/2022', 'numberOfFires': 0}
# {'date': '22/03/2022', 'numberOfFires': 0}
# {'date': '23/03/2022', 'numberOfFires': 0}
# {'date': '24/03/2022', 'numberOfFires': 0}
# {'date': '25/03/2022', 'numberOfFires': 0}
# {'date': '26/03/2022', 'numberOfFires': 0}
# {'date': '27/03/2022', 'numberOfFires': 0}
# {'date': '28/03/2022', 'numberOfFires': 0}
# {'date': '29/03/2022', 'numberOfFires': 0}
# {'date': '30/03/2022', 'numberOfFires': 0}
# {'date': '31/03/2022', 'numberOfFires': 0}
# {'date': '01/04/2022', 'numberOfFires': 0}
# {'date': '02/04/2022', 'numberOfFires': 0}
# {'date': '03/04/2022', 'numberOfFires': 0}
# {'date': '04/04/2022', 'numberOfFires': 0}
# {'date': '05/04/2022', 'numberOfFires': 0}
# {'date': '06/04/2022', 'numberOfFires': 0}
# {'date': '07/04/2022', 'numberOfFires': 0}
# {'date': '08/04/2022', 'numberOfFires': 0}
# {'date': '09/04/2022', 'numberOfFires': 0}
# {'date': '10/04/2022', 'numberOfFires': 0}
# {'date': '11/04/2022', 'numberOfFires': 0}
# {'date': '12/04/2022', 'numberOfFires': 0}
# {'date': '13/04/2022', 'numberOfFires': 0}
# {'date': '14/04/2022', 'numberOfFires': 0}
# {'date': '15/04/2022', 'numberOfFires': 0}
# {'date': '16/04/2022', 'numberOfFires': 0}
# {'date': '17/04/2022', 'numberOfFires': 0}
# {'date': '18/04/2022', 'numberOfFires': 0}
# {'date': '19/04/2022', 'numberOfFires': 0}
# {'date': '20/04/2022', 'numberOfFires': 0}
# {'date': '21/04/2022', 'numberOfFires': 0}
# {'date': '22/04/2022', 'numberOfFires': 0}
# {'date': '23/04/2022', 'numberOfFires': 0}
# {'date': '24/04/2022', 'numberOfFires': 0}
# {'date': '25/04/2022', 'numberOfFires': 0}
# {'date': '26/04/2022', 'numberOfFires': 0}
# {'date': '27/04/2022', 'numberOfFires': 0}
# {'date': '28/04/2022', 'numberOfFires': 0}
# {'date': '29/04/2022', 'numberOfFires': 0}
# {'date': '30/04/2022', 'numberOfFires': 0}
# {'date': '01/05/2022', 'numberOfFires': 0}
# {'date': '02/05/2022', 'numberOfFires': 0}
# {'date': '03/05/2022', 'numberOfFires': 0}
# {'date': '04/05/2022', 'numberOfFires': 0}
# {'date': '05/05/2022', 'numberOfFires': 0}
# {'date': '06/05/2022', 'numberOfFires': 0}
# {'date': '07/05/2022', 'numberOfFires': 0}
# {'date': '08/05/2022', 'numberOfFires': 0}
# {'date': '09/05/2022', 'numberOfFires': 0}
# {'date': '10/05/2022', 'numberOfFires': 0}
# {'date': '11/05/2022', 'numberOfFires': 0}
# {'date': '12/05/2022', 'numberOfFires': 0}
# {'date': '13/05/2022', 'numberOfFires': 0}
# {'date': '14/05/2022', 'numberOfFires': 0}
# {'date': '15/05/2022', 'numberOfFires': 0}
# {'date': '16/05/2022', 'numberOfFires': 0}
# {'date': '17/05/2022', 'numberOfFires': 0}
# {'date': '18/05/2022', 'numberOfFires': 0}
# {'date': '19/05/2022', 'numberOfFires': 0}
# {'date': '20/05/2022', 'numberOfFires': 0}
# {'date': '21/05/2022', 'numberOfFires': 0}
# {'date': '22/05/2022', 'numberOfFires': 0}
# {'date': '23/05/2022', 'numberOfFires': 0}
# {'date': '24/05/2022', 'numberOfFires': 0}
# {'date': '25/05/2022', 'numberOfFires': 0}
# {'date': '26/05/2022', 'numberOfFires': 0}
# {'date': '27/05/2022', 'numberOfFires': 0}
# {'date': '28/05/2022', 'numberOfFires': 0}
# {'date': '29/05/2022', 'numberOfFires': 0}
# {'date': '30/05/2022', 'numberOfFires': 0}
# {'date': '31/05/2022', 'numberOfFires': 0}
# {'date': '01/06/2022', 'numberOfFires': 0}
# {'date': '02/06/2022', 'numberOfFires': 0}
# {'date': '03/06/2022', 'numberOfFires': 0}
# {'date': '04/06/2022', 'numberOfFires': 0}
# {'date': '05/06/2022', 'numberOfFires': 0}
# {'date': '06/06/2022', 'numberOfFires': 0}
# {'date': '07/06/2022', 'numberOfFires': 0}
# {'date': '08/06/2022', 'numberOfFires': 0}
# {'date': '09/06/2022', 'numberOfFires': 0}
# {'date': '10/06/2022', 'numberOfFires': 0}
# {'date': '11/06/2022', 'numberOfFires': 0}
# {'date': '12/06/2022', 'numberOfFires': 0}
# {'date': '13/06/2022', 'numberOfFires': 0}
# {'date': '14/06/2022', 'numberOfFires': 0}
# {'date': '15/06/2022', 'numberOfFires': 0}
# {'date': '16/06/2022', 'numberOfFires': 0}
# {'date': '17/06/2022', 'numberOfFires': 0}
# {'date': '18/06/2022', 'numberOfFires': 0}
# {'date': '19/06/2022', 'numberOfFires': 0}
# {'date': '20/06/2022', 'numberOfFires': 0}
# {'date': '21/06/2022', 'numberOfFires': 0}
# {'date': '22/06/2022', 'numberOfFires': 0}
# {'date': '23/06/2022', 'numberOfFires': 0}
# {'date': '24/06/2022', 'numberOfFires': 0}
# {'date': '25/06/2022', 'numberOfFires': 0}
# {'date': '26/06/2022', 'numberOfFires': 0}
# {'date': '27/06/2022', 'numberOfFires': 0}
# {'date': '28/06/2022', 'numberOfFires': 0}
# {'date': '29/06/2022', 'numberOfFires': 0}
# {'date': '30/06/2022', 'numberOfFires': 0}
# {'date': '01/07/2022', 'numberOfFires': 0}
# {'date': '02/07/2022', 'numberOfFires': 0}
# {'date': '03/07/2022', 'numberOfFires': 0}
# {'date': '04/07/2022', 'numberOfFires': 0}
# {'date': '05/07/2022', 'numberOfFires': 0}
# {'date': '06/07/2022', 'numberOfFires': 0}
# {'date': '07/07/2022', 'numberOfFires': 0}
# {'date': '08/07/2022', 'numberOfFires': 0}
# {'date': '09/07/2022', 'numberOfFires': 0}
# {'date': '10/07/2022', 'numberOfFires': 0}
# {'date': '11/07/2022', 'numberOfFires': 0}
# {'date': '12/07/2022', 'numberOfFires': 0}
# {'date': '13/07/2022', 'numberOfFires': 0}
# {'date': '14/07/2022', 'numberOfFires': 0}
# {'date': '15/07/2022', 'numberOfFires': 0}
# {'date': '16/07/2022', 'numberOfFires': 0}
# {'date': '17/07/2022', 'numberOfFires': 0}
# {'date': '18/07/2022', 'numberOfFires': 0}
# {'date': '19/07/2022', 'numberOfFires': 0}
# {'date': '20/07/2022', 'numberOfFires': 0}
# {'date': '21/07/2022', 'numberOfFires': 0}
# {'date': '22/07/2022', 'numberOfFires': 0}
# {'date': '23/07/2022', 'numberOfFires': 0}
# {'date': '24/07/2022', 'numberOfFires': 0}
# {'date': '25/07/2022', 'numberOfFires': 0}
# {'date': '26/07/2022', 'numberOfFires': 0}
# {'date': '27/07/2022', 'numberOfFires': 0}
# {'date': '28/07/2022', 'numberOfFires': 0}
# {'date': '29/07/2022', 'numberOfFires': 0}
# {'date': '30/07/2022', 'numberOfFires': 0}
# {'date': '31/07/2022', 'numberOfFires': 0}
# {'date': '01/08/2022', 'numberOfFires': 0}
# {'date': '02/08/2022', 'numberOfFires': 0}
# {'date': '03/08/2022', 'numberOfFires': 0}
# {'date': '04/08/2022', 'numberOfFires': 0}
# {'date': '05/08/2022', 'numberOfFires': 0}
# {'date': '06/08/2022', 'numberOfFires': 0}
# {'date': '07/08/2022', 'numberOfFires': 0}
# {'date': '08/08/2022', 'numberOfFires': 0}
# {'date': '09/08/2022', 'numberOfFires': 0}
# {'date': '10/08/2022', 'numberOfFires': 0}
# {'date': '11/08/2022', 'numberOfFires': 0}
# {'date': '12/08/2022', 'numberOfFires': 0}
# {'date': '13/08/2022', 'numberOfFires': 0}
# {'date': '14/08/2022', 'numberOfFires': 0}
# {'date': '15/08/2022', 'numberOfFires': 0}
# {'date': '16/08/2022', 'numberOfFires': 0}
# {'date': '17/08/2022', 'numberOfFires': 0}
# {'date': '18/08/2022', 'numberOfFires': 0}
# {'date': '19/08/2022', 'numberOfFires': 0}
# {'date': '20/08/2022', 'numberOfFires': 0}
# {'date': '21/08/2022', 'numberOfFires': 0}
# {'date': '22/08/2022', 'numberOfFires': 0}
# {'date': '23/08/2022', 'numberOfFires': 0}
# {'date': '24/08/2022', 'numberOfFires': 0}
# {'date': '25/08/2022', 'numberOfFires': 0}
# {'date': '26/08/2022', 'numberOfFires': 0}
# {'date': '27/08/2022', 'numberOfFires': 0}
# {'date': '28/08/2022', 'numberOfFires': 0}
# {'date': '29/08/2022', 'numberOfFires': 0}
# {'date': '30/08/2022', 'numberOfFires': 0}
# {'date': '31/08/2022', 'numberOfFires': 0}
# {'date': '01/09/2022', 'numberOfFires': 0}
# {'date': '02/09/2022', 'numberOfFires': 0}
# {'date': '03/09/2022', 'numberOfFires': 0}
# {'date': '04/09/2022', 'numberOfFires': 0}
# {'date': '05/09/2022', 'numberOfFires': 0}
# {'date': '06/09/2022', 'numberOfFires': 0}
# {'date': '07/09/2022', 'numberOfFires': 0}
# {'date': '08/09/2022', 'numberOfFires': 0}
# {'date': '09/09/2022', 'numberOfFires': 0}
# {'date': '10/09/2022', 'numberOfFires': 0}
# {'date': '11/09/2022', 'numberOfFires': 0}
# {'date': '12/09/2022', 'numberOfFires': 0}
# {'date': '13/09/2022', 'numberOfFires': 0}
# {'date': '14/09/2022', 'numberOfFires': 0}
# {'date': '15/09/2022', 'numberOfFires': 0}
# {'date': '16/09/2022', 'numberOfFires': 0}
# {'date': '17/09/2022', 'numberOfFires': 0}
# {'date': '18/09/2022', 'numberOfFires': 0}
# {'date': '19/09/2022', 'numberOfFires': 0}
# {'date': '20/09/2022', 'numberOfFires': 0}
# {'date': '21/09/2022', 'numberOfFires': 0}
# {'date': '22/09/2022', 'numberOfFires': 0}
# {'date': '23/09/2022', 'numberOfFires': 0}
# {'date': '24/09/2022', 'numberOfFires': 0}
# {'date': '25/09/2022', 'numberOfFires': 0}
# {'date': '26/09/2022', 'numberOfFires': 0}
# {'date': '27/09/2022', 'numberOfFires': 0}
# {'date': '28/09/2022', 'numberOfFires': 0}
# {'date': '29/09/2022', 'numberOfFires': 0}
# {'date': '30/09/2022', 'numberOfFires': 0}
# {'date': '01/10/2022', 'numberOfFires': 8}
# {'date': '02/10/2022', 'numberOfFires': 7}
# {'date': '03/10/2022', 'numberOfFires': 18}
# {'date': '04/10/2022', 'numberOfFires': 5}
# {'date': '05/10/2022', 'numberOfFires': 0}
# {'date': '06/10/2022', 'numberOfFires': 2}
# {'date': '07/10/2022', 'numberOfFires': 1}
# {'date': '08/10/2022', 'numberOfFires': 1}
# {'date': '09/10/2022', 'numberOfFires': 1}
# {'date': '10/10/2022', 'numberOfFires': 3}
# {'date': '11/10/2022', 'numberOfFires': 0}
# {'date': '12/10/2022', 'numberOfFires': 0}
# {'date': '13/10/2022', 'numberOfFires': 0}
# {'date': '14/10/2022', 'numberOfFires': 0}
# {'date': '15/10/2022', 'numberOfFires': 3}
# {'date': '16/10/2022', 'numberOfFires': 1}
# {'date': '17/10/2022', 'numberOfFires': 5}
# {'date': '18/10/2022', 'numberOfFires': 6}
# {'date': '19/10/2022', 'numberOfFires': 0}
# {'date': '20/10/2022', 'numberOfFires': 3}
# {'date': '21/10/2022', 'numberOfFires': 4}
# {'date': '22/10/2022', 'numberOfFires': 0}
# {'date': '23/10/2022', 'numberOfFires': 1}
# {'date': '24/10/2022', 'numberOfFires': 0}
# {'date': '25/10/2022', 'numberOfFires': 0}
# {'date': '26/10/2022', 'numberOfFires': 5}
# {'date': '27/10/2022', 'numberOfFires': 5}
# {'date': '28/10/2022', 'numberOfFires': 1}
# {'date': '29/10/2022', 'numberOfFires': 0}
# {'date': '30/10/2022', 'numberOfFires': 0}
# {'date': '31/10/2022', 'numberOfFires': 0}
# {'date': '01/11/2022', 'numberOfFires': 0}
# {'date': '02/11/2022', 'numberOfFires': 0}
# {'date': '03/11/2022', 'numberOfFires': 0}
# {'date': '04/11/2022', 'numberOfFires': 0}
# {'date': '05/11/2022', 'numberOfFires': 4}
# {'date': '06/11/2022', 'numberOfFires': 0}
# {'date': '07/11/2022', 'numberOfFires': 0}
# {'date': '08/11/2022', 'numberOfFires': 2}
# {'date': '09/11/2022', 'numberOfFires': 10}
# {'date': '10/11/2022', 'numberOfFires': 0}
# {'date': '11/11/2022', 'numberOfFires': 4}
# {'date': '12/11/2022', 'numberOfFires': 5}
# {'date': '13/11/2022', 'numberOfFires': 5}
# {'date': '14/11/2022', 'numberOfFires': 3}
# {'date': '15/11/2022', 'numberOfFires': 0}
# {'date': '16/11/2022', 'numberOfFires': 0}
# {'date': '17/11/2022', 'numberOfFires': 0}
# {'date': '18/11/2022', 'numberOfFires': 0}
# {'date': '19/11/2022', 'numberOfFires': 0}
# {'date': '20/11/2022', 'numberOfFires': 0}
# {'date': '21/11/2022', 'numberOfFires': 1}
# {'date': '22/11/2022', 'numberOfFires': 2}
# {'date': '23/11/2022', 'numberOfFires': 5}
# {'date': '24/11/2022', 'numberOfFires': 0}
# {'date': '25/11/2022', 'numberOfFires': 0}
# {'date': '26/11/2022', 'numberOfFires': 0}
# {'date': '27/11/2022', 'numberOfFires': 0}
# {'date': '28/11/2022', 'numberOfFires': 1}
# {'date': '29/11/2022', 'numberOfFires': 8}
# {'date': '30/11/2022', 'numberOfFires': 31}
# {'date': '01/12/2022', 'numberOfFires': 0}
# {'date': '02/12/2022', 'numberOfFires': 0}
# {'date': '03/12/2022', 'numberOfFires': 0}
# {'date': '04/12/2022', 'numberOfFires': 0}
# {'date': '05/12/2022', 'numberOfFires': 0}
# {'date': '06/12/2022', 'numberOfFires': 0}
# {'date': '07/12/2022', 'numberOfFires': 0}
# {'date': '08/12/2022', 'numberOfFires': 5}
# {'date': '09/12/2022', 'numberOfFires': 4}
# {'date': '10/12/2022', 'numberOfFires': 2}
# {'date': '11/12/2022', 'numberOfFires': 0}
# {'date': '12/12/2022', 'numberOfFires': 1}
# {'date': '13/12/2022', 'numberOfFires': 1}
# {'date': '14/12/2022', 'numberOfFires': 1}
# {'date': '15/12/2022', 'numberOfFires': 4}
# {'date': '16/12/2022', 'numberOfFires': 15}
# {'date': '17/12/2022', 'numberOfFires': 0}
# {'date': '18/12/2022', 'numberOfFires': 0}
# {'date': '19/12/2022', 'numberOfFires': 0}
# {'date': '20/12/2022', 'numberOfFires': 0}
# {'date': '21/12/2022', 'numberOfFires': 1}
# {'date': '22/12/2022', 'numberOfFires': 0}
# {'date': '23/12/2022', 'numberOfFires': 0}
# {'date': '24/12/2022', 'numberOfFires': 1}
# {'date': '25/12/2022', 'numberOfFires': 1}
# {'date': '26/12/2022', 'numberOfFires': 0}
# {'date': '27/12/2022', 'numberOfFires': 4}
# {'date': '28/12/2022', 'numberOfFires': 0}
# {'date': '29/12/2022', 'numberOfFires': 0}
# {'date': '30/12/2022', 'numberOfFires': 0}
# {'date': '31/12/2022', 'numberOfFires': 0}
# {'date': '01/01/2023', 'numberOfFires': 0}

# %%
result = collection.aggregate(
    [{'$unwind': '$hotspots'}, {'$match': {'hotspots.confidence': {'$lt': 70}}}, {'$project': {'_id': 0, 'hotspots': 1}}])

for each in result:
    pprint(each)
# Out:
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.463,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 34.0,
#               'time': datetime.datetime(2022, 10, 1, 15, 13, 56)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.46,
#               'longitude': 148.113,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2022, 10, 1, 4, 10, 28)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.466,
#               'longitude': 148.1,
#               'surface_temperature_celcius': 29.0,
#               'time': datetime.datetime(2022, 10, 2, 23, 44, 31)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.475,
#               'longitude': 148.134,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2022, 10, 2, 4, 53, 10)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.456,
#               'longitude': 148.11,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2022, 10, 2, 0, 39, 34)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.461,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2022, 10, 3, 15, 1, 44)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.236,
#               'longitude': 141.176,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 28)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.227,
#               'longitude': 141.151,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2022, 10, 3, 3, 58, 28)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.227,
#               'longitude': 141.146,
#               'surface_temperature_celcius': 31.0,
#               'time': datetime.datetime(2022, 10, 3, 1, 22, 44)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.418,
#               'longitude': 141.596,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 10, 4, 4, 41, 36)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.288,
#               'longitude': 144.39,
#               'surface_temperature_celcius': 36.0,
#               'time': datetime.datetime(2022, 10, 16, 23, 56, 43)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.587,
#               'longitude': 142.479,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 10, 17, 4, 10, 38)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.296,
#               'longitude': 144.386,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 10, 20, 0, 27, 12)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.1,
#               'longitude': 143.772,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2022, 10, 21, 1, 9, 54)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.156,
#               'longitude': 143.568,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 10, 26, 4, 4, 53)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.152,
#               'longitude': 143.578,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2022, 10, 26, 4, 4, 53)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.748,
#               'longitude': 144.168,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2022, 10, 27, 4, 47, 31)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.538,
#               'longitude': 141.129,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2022, 11, 8, 5, 12, 8)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.759,
#               'longitude': 145.179,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 56)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.758,
#               'longitude': 145.19,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 56)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.719,
#               'longitude': 142.154,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 11, 9, 4, 16, 46)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -36.943,
#               'longitude': 143.286,
#               'surface_temperature_celcius': 29.0,
#               'time': datetime.datetime(2022, 11, 11, 15, 8)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.942,
#               'longitude': 143.282,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2022, 11, 12, 4, 47, 32)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.864,
#               'longitude': 144.174,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 11, 12, 4, 47, 16)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.912,
#               'longitude': 146.272,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2022, 11, 12, 4, 46, 53)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.942,
#               'longitude': 143.292,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 11, 12, 0, 33, 15)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.954,
#               'longitude': 143.918,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 13, 3, 52, 8)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -38.167,
#               'longitude': 143.841,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2022, 11, 13, 1, 16, 38)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -38.16,
#               'longitude': 143.803,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 11, 13, 1, 16, 37)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.527,
#               'longitude': 143.493,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2022, 11, 14, 0, 21, 26)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.332,
#               'longitude': 143.375,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2022, 11, 14, 0, 21, 7)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.141,
#               'longitude': 143.183,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2022, 11, 23, 0, 15, 12)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.952,
#               'longitude': 144.972,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2022, 11, 23, 0, 14, 47)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.749,
#               'longitude': 148.297,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 28, 0, 33, 14)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.611,
#               'longitude': 149.277,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2022, 11, 29, 13, 17, 24)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.605,
#               'longitude': 149.308,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2022, 11, 29, 13, 17, 24)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -34.282,
#               'longitude': 142.121,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 53, 16)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.605,
#               'longitude': 149.326,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2022, 11, 29, 3, 52, 10)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2022, 11, 30, 23, 25, 57)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 36)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 36)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 35)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31.0,
#               'time': datetime.datetime(2022, 11, 30, 15, 38, 32)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32.0,
#               'time': datetime.datetime(2022, 11, 30, 12, 22, 15)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2022, 11, 30, 4, 34, 57)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 21)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 53)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2022, 11, 30, 0, 20, 49)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.291,
#               'longitude': 146.159,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2022, 12, 8, 13, 11, 43)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.987,
#               'longitude': 144.005,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2022, 12, 10, 0, 57, 59)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -34.289,
#               'longitude': 141.712,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 12, 10, 0, 56, 57)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2022, 12, 12, 0, 45, 38)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.623,
#               'longitude': 149.323,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2022, 12, 15, 13, 17, 17)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -38.038,
#               'longitude': 142.986,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2022, 12, 15, 1, 16, 23)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.624,
#               'longitude': 149.332,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2022, 12, 16, 15, 38, 39)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.82,
#               'longitude': 142.323,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 35, 15)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.644,
#               'longitude': 149.346,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2022, 12, 16, 4, 34, 57)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -38.046,
#               'longitude': 144.201,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2022, 12, 16, 0, 21, 11)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.63,
#               'longitude': 149.335,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2022, 12, 16, 0, 20, 53)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -35.646,
#               'longitude': 142.282,
#               'surface_temperature_celcius': 32.0,
#               'time': datetime.datetime(2022, 12, 24, 13, 12, 1)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.554,
#               'longitude': 143.307,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2022, 12, 27, 0, 2, 15)}}

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$group': {
    '_id': '$date', 'avgTemp': {'$avg': '$hotspots.surface_temperature_celcius'}}}])

for each in result:
    pprint({
        'date': each['_id'].strftime("%d/%m/%Y"),
        'avgTemp': each['avgTemp']
    })
# Out:
# {'avgTemp': 38.0, 'date': '23/10/2022'}
# {'avgTemp': 59.0, 'date': '21/11/2022'}
# {'avgTemp': 50.4, 'date': '27/10/2022'}
# {'avgTemp': 58.25, 'date': '09/12/2022'}
# {'avgTemp': 52.166666666666664, 'date': '18/10/2022'}
# {'avgTemp': 46.25, 'date': '11/11/2022'}
# {'avgTemp': 53.333333333333336, 'date': '10/10/2022'}
# {'avgTemp': 36.0, 'date': '16/10/2022'}
# {'avgTemp': 43.57142857142857, 'date': '02/10/2022'}
# {'avgTemp': 58.8, 'date': '23/11/2022'}
# {'avgTemp': 60.625, 'date': '29/11/2022'}
# {'avgTemp': 52.0, 'date': '14/11/2022'}
# {'avgTemp': 58.5, 'date': '05/11/2022'}
# {'avgTemp': 47.0, 'date': '13/11/2022'}
# {'avgTemp': 50.6, 'date': '08/12/2022'}
# {'avgTemp': 70.0, 'date': '14/12/2022'}
# {'avgTemp': 42.0, 'date': '28/11/2022'}
# {'avgTemp': 57.8, 'date': '16/12/2022'}
# {'avgTemp': 51.6, 'date': '17/10/2022'}
# {'avgTemp': 62.75, 'date': '27/12/2022'}
# {'avgTemp': 32.0, 'date': '24/12/2022'}
# {'avgTemp': 53.0, 'date': '12/11/2022'}
# {'avgTemp': 45.5, 'date': '08/11/2022'}
# {'avgTemp': 61.3, 'date': '09/11/2022'}
# {'avgTemp': 44.0, 'date': '12/12/2022'}
# {'avgTemp': 41.0, 'date': '08/10/2022'}
# {'avgTemp': 48.25, 'date': '01/10/2022'}
# {'avgTemp': 44.0, 'date': '06/10/2022'}
# {'avgTemp': 61.5, 'date': '22/11/2022'}
# {'avgTemp': 42.0, 'date': '07/10/2022'}
# {'avgTemp': 44.0, 'date': '09/10/2022'}
# {'avgTemp': 39.0, 'date': '15/12/2022'}
# {'avgTemp': 52.41935483870968, 'date': '30/11/2022'}
# {'avgTemp': 50.0, 'date': '03/10/2022'}
# {'avgTemp': 46.0, 'date': '21/12/2022'}
# {'avgTemp': 56.0, 'date': '28/10/2022'}
# {'avgTemp': 44.6, 'date': '26/10/2022'}
# {'avgTemp': 46.0, 'date': '10/12/2022'}
# {'avgTemp': 51.25, 'date': '21/10/2022'}
# {'avgTemp': 54.0, 'date': '25/12/2022'}
# {'avgTemp': 60.0, 'date': '13/12/2022'}
# {'avgTemp': 50.0, 'date': '20/10/2022'}
# {'avgTemp': 49.0, 'date': '04/10/2022'}
# {'avgTemp': 72.66666666666667, 'date': '15/10/2022'}

# %%
result = collection.aggregate([{'$sort': {'ghi': 1}}, {'$limit': 10}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('647f20bc02b5db9ca3359d24'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2022, 8, 2, 0, 0),
#  'ghi': 47.0,
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d03'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2022, 6, 30, 0, 0),
#  'ghi': 48.0,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d04'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2022, 7, 1, 0, 0),
#  'ghi': 49.0,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d0e'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2022, 7, 11, 0, 0),
#  'ghi': 56.0,
#  'max_wind_speed': 5.1,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d12'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2022, 7, 15, 0, 0),
#  'ghi': 57.0,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d05'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2022, 7, 2, 0, 0),
#  'ghi': 60.0,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'_id': ObjectId('647f20bc02b5db9ca3359d23'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2022, 8, 1, 0, 0),
#  'ghi': 65.0,
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'_id': ObjectId('647f20bc02b5db9ca3359d17'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2022, 7, 20, 0, 0),
#  'ghi': 65.0,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d22'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2022, 7, 31, 0, 0),
#  'ghi': 65.0,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d35'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2022, 8, 19, 0, 0),
#  'ghi': 66.0,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.04,
#  'precipitation_type': 'G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %%
result = collection.aggregate(
    [{'$match': {'precipitation_type': 'G', 'precipitation': {'$gte': 0.20, '$lte': 0.35}}}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('647f20bc02b5db9ca3359c5b'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2022, 1, 13, 0, 0),
#  'ghi': 157.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'_id': ObjectId('647f20bc02b5db9ca3359ca6'),
#  'air_temperature_celcius': 17.0,
#  'date': datetime.datetime(2022, 3, 29, 0, 0),
#  'ghi': 146.0,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('647f20bc02b5db9ca3359cbc'),
#  'air_temperature_celcius': 20.0,
#  'date': datetime.datetime(2022, 4, 20, 0, 0),
#  'ghi': 166.0,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'_id': ObjectId('647f20bc02b5db9ca3359cc2'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 4, 26, 0, 0),
#  'ghi': 102.0,
#  'max_wind_speed': 20.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('647f20bc02b5db9ca3359ce1'),
#  'air_temperature_celcius': 14.0,
#  'date': datetime.datetime(2022, 5, 27, 0, 0),
#  'ghi': 122.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.35,
#  'precipitation_type': 'G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'_id': ObjectId('647f20bc02b5db9ca3359ce4'),
#  'air_temperature_celcius': 8.0,
#  'date': datetime.datetime(2022, 5, 30, 0, 0),
#  'ghi': 73.0,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'_id': ObjectId('647f20bc02b5db9ca3359d06'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 7, 3, 0, 0),
#  'ghi': 98.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'_id': ObjectId('647f20bc02b5db9ca3359d1e'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 7, 27, 0, 0),
#  'ghi': 99.0,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d28'),
#  'air_temperature_celcius': 9.0,
#  'date': datetime.datetime(2022, 8, 6, 0, 0),
#  'ghi': 83.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'_id': ObjectId('647f20bc02b5db9ca3359d3c'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 8, 26, 0, 0),
#  'ghi': 102.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d46'),
#  'air_temperature_celcius': 8.0,
#  'date': datetime.datetime(2022, 9, 5, 0, 0),
#  'ghi': 75.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'_id': ObjectId('647f20bc02b5db9ca3359d48'),
#  'air_temperature_celcius': 10.0,
#  'date': datetime.datetime(2022, 9, 7, 0, 0),
#  'ghi': 90.0,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'_id': ObjectId('647f20bc02b5db9ca3359d50'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 9, 15, 0, 0),
#  'ghi': 97.0,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'_id': ObjectId('647f20bc02b5db9ca3359d64'),
#  'air_temperature_celcius': 12.0,
#  'date': datetime.datetime(2022, 10, 5, 0, 0),
#  'ghi': 105.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'_id': ObjectId('647f20bc02b5db9ca3359d7c'),
#  'air_temperature_celcius': 17.0,
#  'date': datetime.datetime(2022, 10, 29, 0, 0),
#  'ghi': 152.0,
#  'max_wind_speed': 27.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d7d'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2022, 10, 30, 0, 0),
#  'ghi': 100.0,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('647f20bc02b5db9ca3359d8e'),
#  'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2022, 11, 16, 0, 0),
#  'ghi': 140.0,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'_id': ObjectId('647f20bc02b5db9ca3359d8f'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2022, 11, 17, 0, 0),
#  'ghi': 151.0,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'_id': ObjectId('647f20bc02b5db9ca3359d9c'),
#  'air_temperature_celcius': 26.0,
#  'date': datetime.datetime(2022, 11, 30, 0, 0),
#  'ghi': 202.0,
#  'hotspots': [{'confidence': 52.0,
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celcius': 47.0,
#                'time': datetime.datetime(2022, 11, 30, 23, 25, 57)},
#               {'confidence': 100.0,
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 53.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 36)},
#               {'confidence': 51.0,
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 36)},
#               {'confidence': 64.0,
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 36)},
#               {'confidence': 100.0,
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 54.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 35)},
#               {'confidence': 69.0,
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celcius': 35.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 35)},
#               {'confidence': 100.0,
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celcius': 49.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 35)},
#               {'confidence': 61.0,
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celcius': 31.0,
#                'time': datetime.datetime(2022, 11, 30, 15, 38, 32)},
#               {'confidence': 62.0,
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celcius': 33.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 64.0,
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celcius': 32.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 84.0,
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celcius': 38.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 81.0,
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celcius': 55.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celcius': 65.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celcius': 71.0,
#                'time': datetime.datetime(2022, 11, 30, 12, 22, 14)},
#               {'confidence': 84.0,
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 59.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 35)},
#               {'confidence': 73.0,
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 35)},
#               {'confidence': 98.0,
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celcius': 83.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#               {'confidence': 81.0,
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celcius': 57.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#               {'confidence': 84.0,
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celcius': 61.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#               {'confidence': 99.0,
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celcius': 86.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#               {'confidence': 69.0,
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celcius': 48.0,
#                'time': datetime.datetime(2022, 11, 30, 4, 34, 57)},
#               {'confidence': 60.0,
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 21)},
#               {'confidence': 83.0,
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celcius': 58.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 87.0,
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celcius': 63.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 95.0,
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celcius': 76.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 81.0,
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celcius': 56.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 73.0,
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 81.0,
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 55.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 69.0,
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 53)},
#               {'confidence': 64.0,
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celcius': 41.0,
#                'time': datetime.datetime(2022, 11, 30, 0, 20, 49)}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# # question 3
#
#
#
# Single-field indexes:
#
# date: It will be useful for tasks like finding climate data on a specific date, querying data for a range of dates, and finding the number of hotspot incidents each day. Thereby increasing efficiency of date based query execution involving sorting and date specific queries.
#
# hotspots.confidence: the performance of queries that involve filtering by confidence values can be improved using index for confidence. It will be useful for tasks like finding records with a specific confidence range and finding records with confidence below a certain threshold.
#
#
# Compound indexes:
#
# "date": 1, "hotspots.surface_temperature_celcius": 1: This way it woul dbe beneficial for tasks that involve filtering data based on both date and surface temperature. It will optimize queries like finding surface temperature within a specific range on a particular date and finding the top records with the highest surface temperature.
#
# Similarly multiple combinations of date with other factors like wind speed and air temperature, relative humidity for achieving better performance for query based on climate attributes involving date based search.
#
#
# Using MongoDB's sharding feature to distribute data across multiple servers, allowing for horizontal scalability and increased write throughput.
